# %%
import numpy as np 
import pandas as pd
Netflix = pd.read_csv('./NTFLX.csv')
Netflix.info()
import warnings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
#  7   Company    1258 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 78.8+ KB

# %%
warnings.filterwarnings('ignore')

# %%
Netflix.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  07-08-2017  181.000000  182.270004  179.100006  181.330002  181.330002
# 1  08-08-2017  181.369995  181.910004  177.449997  178.360001  178.360001
# 2  09-08-2017  171.429993  175.960007  170.009995  175.779999  175.779999
# 3  10-08-2017  174.029999  174.449997  167.600006  169.139999  169.139999
# 4  11-08-2017  169.860001  172.580002  169.000000  171.399994  171.399994
#
#     Volume Company
# 0  4609800   NTFLX
# 1  6104000   NTFLX
# 2  9670500   NTFLX
# 3  9693100   NTFLX
# 4  5022300   NTFLX

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Netflix['Date'] = pd.to_datetime(Netflix['Date'])
print(Netflix)
print (Netflix.dtypes)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2017-07-08  181.000000  182.270004  179.100006  181.330002  181.330002
# 1    2017-08-08  181.369995  181.910004  177.449997  178.360001  178.360001
# 2    2017-09-08  171.429993  175.960007  170.009995  175.779999  175.779999
# 3    2017-10-08  174.029999  174.449997  167.600006  169.139999  169.139999
# 4    2017-11-08  169.860001  172.580002  169.000000  171.399994  171.399994
# ...         ...         ...         ...         ...         ...         ...
# 1253 2022-07-29  223.289993  230.750000  222.399994  224.899994  224.899994
# 1254 2022-01-08  223.100006  228.389999  221.000000  226.210007  226.210007
# 1255 2022-02-08  222.759995  228.199997  220.880005  221.419998  221.419998
# 1256 2022-03-08  224.789993  228.100006  222.419998  226.729996  226.729996
# 1257 2022-04-08  227.679993  232.070007  225.050003  229.910004  229.910004
#
#        Volume Company
# 0     4609800   NTFLX
# ...

# %%
Netflix.set_index('Date', inplace=True)
Netflix.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-07-08  181.000000  182.270004  179.100006  181.330002  181.330002
# 2017-08-08  181.369995  181.910004  177.449997  178.360001  178.360001
# 2017-09-08  171.429993  175.960007  170.009995  175.779999  175.779999
# 2017-10-08  174.029999  174.449997  167.600006  169.139999  169.139999
# 2017-11-08  169.860001  172.580002  169.000000  171.399994  171.399994
#
#              Volume Company
# Date
# 2017-07-08  4609800   NTFLX
# 2017-08-08  6104000   NTFLX
# 2017-09-08  9670500   NTFLX
# 2017-10-08  9693100   NTFLX
# 2017-11-08  5022300   NTFLX

# %%
Netflix. drop('Company', axis=1, inplace=True)
Netflix
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-07-08  181.000000  182.270004  179.100006  181.330002  181.330002
# 2017-08-08  181.369995  181.910004  177.449997  178.360001  178.360001
# 2017-09-08  171.429993  175.960007  170.009995  175.779999  175.779999
# 2017-10-08  174.029999  174.449997  167.600006  169.139999  169.139999
# 2017-11-08  169.860001  172.580002  169.000000  171.399994  171.399994
# ...                ...         ...         ...         ...         ...
# 2022-07-29  223.289993  230.750000  222.399994  224.899994  224.899994
# 2022-01-08  223.100006  228.389999  221.000000  226.210007  226.210007
# 2022-02-08  222.759995  228.199997  220.880005  221.419998  221.419998
# 2022-03-08  224.789993  228.100006  222.419998  226.729996  226.729996
# 2022-04-08  227.679993  232.070007  225.050003  229.910004  229.910004
#
#              Volume
# Date
# 2017-07-08  4609800
# 2017-08-08  6104000
# 2017-09-08  9670500
# ...

# %%
import matplotlib.pyplot as plt
Netflix.plot(subplots=True, figsize=(10,12))
plt.title('Netflix stock attributes')
plt.savefig('stocks.png')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Netflix['2020':'2021'].plot(subplots=True, figsize=(10,12))
plt.title('Netflix stock attributes')
plt.savefig('stocks.png')
plt.show()

# %%
Netflix['Daily Return'] = Netflix['Adj Close'].pct_change()
Netflix10 = Netflix.sort_values(by=['Daily Return'],ascending=False)
Netflix10 = Netflix10[0:10]
Netflix10[['Daily Return']]
# Out:
#             Daily Return
# Date
# 2021-01-20      0.168543
# 2020-08-26      0.116087
# 2022-01-31      0.111302
# 2018-01-23      0.099789
# 2019-04-01      0.097234
# 2018-04-17      0.091884
# 2018-12-26      0.084616
# 2020-03-23      0.082445
# 2022-07-15      0.081989
# 2020-10-07      0.080688
